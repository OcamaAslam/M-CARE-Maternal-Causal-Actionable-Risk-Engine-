# %% [markdown]
# # M-CARE (Maternal Causal Actionable Risk Engine)

# %% [markdown]
# ## TabPFN
# TabPFN (Tabular Prior-Fitted Network) is a groundbreaking foundation model for tabular data, leveraging a Transformer architecture pre-trained on a massive, diverse collection of synthetic datasets to internalize a strong, general prior over what constitutes a typical tabular classification or regression problem. This extensive pre-training allows TabPFN to bypass traditional, time-consuming model training and hyperparameter optimization steps for new tasks. Instead, when presented with a small-to-medium new dataset (ideally $\leq 50,000$ rows), it uses this new data as context and applies its pre-learned knowledge to make highly accurate predictions almost instantaneously, operating in an "in-context learning" manner similar to large language models. This unique working principle makes it a state-of-the-art solution for rapid, off-the-shelf deployment in scenarios where data is scarce or prediction speed is critical.
#
# ## SHAP-IQ
# SHAP-IQ is a game-theoretic framework and Python library designed to quantify higher-order feature interactions (of any order) in machine learning models, extending beyond the individual feature attributions of standard SHAP. This allows users to uncover and visualize complex dependencies within black-box models that traditional "first-order" explainability methods fail to capture.

# %%
! pip install tabpfn dice-ml shapiq gtts
# Out:
# Requirement already satisfied: tabpfn in /usr/local/lib/python3.12/dist-packages (6.2.0)
# Requirement already satisfied: dice-ml in /usr/local/lib/python3.12/dist-packages (0.12)
# Requirement already satisfied: shapiq in /usr/local/lib/python3.12/dist-packages (1.4.1)
# Requirement already satisfied: gtts in /usr/local/lib/python3.12/dist-packages (2.5.4)
# Requirement already satisfied: torch<3,>=2.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.9.0+cu126)
# Requirement already satisfied: numpy<3,>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.0.2)
# Requirement already satisfied: scikit-learn<1.8,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.6.1)
# Requirement already satisfied: typing_extensions>=4.12.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (4.15.0)
# Requirement already satisfied: scipy<2,>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.16.3)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.2.2)
# Requirement already satisfied: einops<0.9,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.8.1)
# Requirement already satisfied: huggingface-hub<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.36.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.12.3)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.12.0)
# Requirement already satisfied: eval-type-backport>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.5.3)
# Requirement already satisfied: tabpfn-common-utils>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (0.2.12)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from dice-ml) (4.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from dice-ml) (4.67.1)
# Requirement already satisfied: raiutils>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dice-ml) (0.4.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (from dice-ml) (3.1.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from dice-ml) (4.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from shapiq) (2.32.5)
# Requirement already satisfied: sparse-transform in /usr/local/lib/python3.12/dist-packages (from shapiq) (0.2.1)
# Requirement already satisfied: galois in /usr/local/lib/python3.12/dist-packages (from shapiq) (0.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from shapiq) (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from shapiq) (3.6.1)
# Requirement already satisfied: colour in /usr/local/lib/python3.12/dist-packages (from shapiq) (0.1.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from shapiq) (11.3.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.12/dist-packages (from gtts) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.10.1->tabpfn) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->shapiq) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->shapiq) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->shapiq) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->shapiq) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8,>=1.2.0->tabpfn) (3.6.0)
# Requirement already satisfied: platformdirs>=4 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (4.5.1)
# Requirement already satisfied: posthog~=6.7 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (6.9.3)
# Requirement already satisfied: ruff>=0.11.6 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (0.14.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.5.0)
# Requirement already satisfied: numba>=0.55 in /usr/local/lib/python3.12/dist-packages (from galois->shapiq) (0.60.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->dice-ml) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->dice-ml) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->dice-ml) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->dice-ml) (0.30.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->shapiq) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->shapiq) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->shapiq) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->shapiq) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->shapiq) (3.2.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.55->galois->shapiq) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (1.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.1->tabpfn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.1->tabpfn) (3.0.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from tabpfn import TabPFNClassifier
import dice_ml
import shapiq
from openai import OpenAI
from gtts import gTTS
import os
from huggingface_hub import login
from google.colab import userdata
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
login(token=userdata.get('HF_TOKEN'))

# %% [markdown]
# ## About the dataset
#
# This dataset comprises detailed clinical, physiological, and historical health information collected from maternal patients to evaluate potential health risks during pregnancy.
# It serves as a resource for developing predictive models aimed at identifying and managing high-risk pregnancies, providing insights into maternal health factors, and supporting personalized patient care.
# The dataset is well-suited for research in obstetrics, predictive health modeling, and maternal healthcare management.
#
# Acknowledgement
#
# Mojumdar, Mayen Uddin ; Assaduzzaman, Md; Sarker, Dhiman; Shifa, Hasin Arman; Sajeeb, Md. Anisul Haque; Bari , Shadikul; Chakraborty, Narayan Ranjan; Alam, Mohammad Jahangir (2024), “Maternal Health Risk Assessment Dataset”, Mendeley Data, V1, doi: [10.17632/p5w98dvbbk.1](https://)

# %%
# Load Data (Replace with your actual path)

df = pd.read_csv('/content/Dataset - Updated.csv')

display(df.head())

display(df.info())

display(df.describe())
# Out:
#    Age  Systolic BP  Diastolic   BS  Body Temp   BMI  Previous Complications  \
# 0   22         90.0       60.0  9.0        100  18.0                     1.0
# 1   22        110.0       70.0  7.1         98  20.4                     0.0
# 2   27        110.0       70.0  7.5         98  23.0                     1.0
# 3   20        100.0       70.0  7.2         98  21.2                     0.0
# 4   20         90.0       60.0  7.5         98  19.7                     0.0
#
#    Preexisting Diabetes  Gestational Diabetes  Mental Health  Heart Rate  \
# 0                   1.0                     0              1        80.0
# 1                   0.0                     0              0        74.0
# 2                   0.0                     0              0        72.0
# 3                   0.0                     0              0        74.0
# 4                   0.0                     0              0        74.0
#
#   Risk Level
# 0       High
# 1        Low
# 2        Low
# 3        Low
# 4        Low
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     1205 non-null   int64
#  1   Systolic BP             1200 non-null   float64
#  2   Diastolic               1201 non-null   float64
#  3   BS                      1203 non-null   float64
#  4   Body Temp               1205 non-null   int64
#  5   BMI                     1187 non-null   float64
#  6   Previous Complications  1203 non-null   float64
#  7   Preexisting Diabetes    1203 non-null   float64
#  8   Gestational Diabetes    1205 non-null   int64
#  9   Mental Health           1205 non-null   int64
#  10  Heart Rate              1203 non-null   float64
#  11  Risk Level              1187 non-null   object
# dtypes: float64(7), int64(4), object(1)
# memory usage: 113.1+ KB
# None
#                Age  Systolic BP    Diastolic           BS    Body Temp  \
# count  1205.000000  1200.000000  1201.000000  1203.000000  1205.000000
# mean     27.731950   116.819167    77.166528     7.501064    98.395851
# std      12.571074    18.715502    14.305148     3.049522     1.088363
# min      10.000000    70.000000    40.000000     3.000000    97.000000
# 25%      21.000000   100.000000    65.000000     6.000000    98.000000
# 50%      25.000000   120.000000    80.000000     6.900000    98.000000
# 75%      32.000000   130.000000    90.000000     7.900000    98.000000
# max     325.000000   200.000000   140.000000    19.000000   103.000000
#
#                BMI  Previous Complications  Preexisting Diabetes  \
# count  1187.000000             1203.000000           1203.000000
# mean     23.315080                0.175395              0.288446
# std       3.875682                0.380463              0.453228
# min       0.000000                0.000000              0.000000
# 25%      20.450000                0.000000              0.000000
# 50%      23.000000                0.000000              0.000000
# 75%      25.000000                0.000000              1.000000
# max      37.000000                1.000000              1.000000
#
#        Gestational Diabetes  Mental Health   Heart Rate
# count           1205.000000     1205.00000  1203.000000
# mean               0.117842        0.33444    75.817124
# std                0.322555        0.47199     7.227338
# min                0.000000        0.00000    58.000000
# 25%                0.000000        0.00000    70.000000
# 50%                0.000000        0.00000    76.000000
# 75%                0.000000        1.00000    80.000000
# max                1.000000        1.00000    92.000000

# %%
# Map Target: High -> 1, Low -> 0

df['Risk Level'] = df['Risk Level'].astype(str).str.strip().str.lower()
df['Risk Level'] = df['Risk Level'].map({'high': 1, 'low': 0})
df = df.dropna(subset=['Risk Level'])
df['Risk Level'] = df['Risk Level'].astype(int)

target_col = 'Risk Level'
feature_names = [c for c in df.columns if c != target_col]

X = df[feature_names]
y = df[target_col]

# Split Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ## TabPFN Model

# %%
print("Training TabPFN (Transformer)...")
clf = TabPFNClassifier() # kept low for speed
clf.fit(X_train, y_train)
# Out:
# Training TabPFN (Transformer)...
# TabPFNClassifier()

# %%
# predictions

y_pred = clf.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
# confusion matrix
cm = confusion_matrix(y_test, y_pred)
class_labels = clf.classes_ if hasattr(clf, 'classes_') else None

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy Score: {accuracy:.4f}")
# Out:
# Accuracy Score: 0.9916

# %% [markdown]
# ## Interpretability: Explain TabPFN predictions with SHAP values and Dice-ML

# %%
# Select a High Risk Patient

# We want to explain a patient who is PREDICTED as High Risk (Class 1)
high_risk_indices = np.where(y_pred == 1)[0]

if len(high_risk_indices) == 0:
    print("No High Risk patients found in test set to analyze.")
else:
    idx_in_test = high_risk_indices[11] # can be any patient, we selected index 11
    patient_data_series = X_test.iloc[idx_in_test] # for SHAP
    patient_data_df = X_test.iloc[[idx_in_test]] # Keep as DataFrame for DiCE

    print(f"\nAnalyzing Patient Index: {idx_in_test}")
    print(f"Current Prediction: HIGH RISK")
# Out:
# Analyzing Patient Index: 28
# Current Prediction: HIGH RISK

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn')

# SHAPIQ: Why?
print("\n--- [DIAGNOSIS] SHAPIQ EXPLANATION ---")

# Define a wrapper for probability of Class 1 (High Risk)
def predict_proba_positive(data_array):
    return clf.predict_proba(data_array)[:, 1]

# We explain the interactions for the "High Risk" class
explainer = shapiq.Explainer(
    model=predict_proba_positive,
    data=X_train.values,
    class_index=None # We are manually returning the proba for class 1 above
)

# Explain the specific patient
print("Calculating feature interactions")
explanation = explainer.explain(
    patient_data_series.values,
    budget=50  # Lower budget for demo speed; increase for precision
)
# Out:
# --- [DIAGNOSIS] SHAPIQ EXPLANATION ---
# Calculating feature interactions

# %%
# Plot

explanation.plot_force(feature_names=X.columns.tolist())
plt.show()

explanation.plot_waterfall(feature_names=X.columns.tolist())
plt.show()

# %%
# DiCE: How to Fix?

print("\n--- [PRESCRIPTION] DiCE COUNTERFACTUALS ---")
print("Optimization Constraints: Locking History & Enforcing Normal Ranges...")
print("***"*50)

# Setup DiCE Data
d = dice_ml.Data(dataframe=df, continuous_features=feature_names, outcome_name=target_col)

# Setup DiCE Model
m = dice_ml.Model(model=clf, backend="sklearn")

# Initialize
exp = dice_ml.Dice(d, m, method="random")

# Define Clinical Constraints (Safety Bounds)
# Only allow changes to actionable features

actionable = ['Systolic BP', 'Diastolic', 'BS', 'BMI', 'Body Temp', 'Heart Rate']
valid_actionable = [c for c in actionable if c in X.columns]

# Define Medical Safety Ranges
safety_bounds = {
    'Systolic BP': [90, 120],
    'Diastolic': [60, 80],
    'BS': [3.9, 7.8],
    'BMI': [18.5, 24.9],
    'Body Temp': [97, 99]
}

# Filter bounds to only include columns present in data
valid_bounds = {k: v for k, v in safety_bounds.items() if k in valid_actionable}

# Generate Plan
dice_exp = exp.generate_counterfactuals(
    patient_data_df,
    total_CFs=1,
    desired_class=0,
    features_to_vary=valid_actionable,
    permitted_range=valid_bounds
)

# Interpreted Plan
cf_df = dice_exp.cf_examples_list[0].final_cfs_df
if not cf_df.empty:
    suggestion = cf_df.iloc[0]
    original = patient_data_series

    original_vitals = {col: round(original[col], 1) for col in valid_actionable}
    suggested_vitals = {col: round(suggestion[col], 1) for col in valid_actionable}

    print(f"\nOriginal Vitals: {original_vitals}")
    print(f"Suggested Vitals: {suggested_vitals}")

    print(f"\nAI Doctor Prescription:")
    for col in valid_actionable:
        diff = suggestion[col] - original[col]
        if abs(diff) > 0.1:
            direction = "Reduce" if diff < 0 else "Increase"
            print(f"  - {direction} {col} by {abs(diff):.1f} (Target: {suggestion[col]:.1f})")
else:
    print("No medically safe path found for this patient.")
# Out:
# --- [PRESCRIPTION] DiCE COUNTERFACTUALS ---
# Optimization Constraints: Locking History & Enforcing Normal Ranges...
# ******************************************************************************************************************************************************
# 100%|██████████| 1/1 [00:03<00:00,  3.51s/it]
# Original Vitals: {'Systolic BP': np.float64(130.0), 'Diastolic': np.float64(80.0), 'BS': np.float64(7.0), 'BMI': np.float64(27.5), 'Body Temp': np.float64(98.0), 'Heart Rate': np.float64(82.0)}
# Suggested Vitals: {'Systolic BP': np.float64(112.3), 'Diastolic': np.float64(80.0), 'BS': np.float64(7.0), 'BMI': np.float64(20.0), 'Body Temp': np.float64(98.0), 'Heart Rate': np.float64(82.0)}
#
# AI Doctor Prescription:
#   - Reduce Systolic BP by 17.7 (Target: 112.3)
#   - Reduce BMI by 7.5 (Target: 20.0)

# %% [markdown]
# ## Conclusions
#
# Our analysis:
#
# * **Dataset:** Utilized the **Mendely Maternal Health Risk Assessment** dataset with a binary target: High vs. Low Risk.
# * **Model:** Employed **TabPFN (Tabular Prior-Fitted Network)** for classification.
# * **Performance:** Achieved outstanding performance with **0.9916 Accuracy**.
# * **Interpretability Framework:**
#     * **Why?** Used **SHAP** to explain feature importance and model decisions.
#     * **How to Fix?** Used **Dice-ML** to generate actionable **counterfactuals** (suggestions for minimal changes to shift risk from high to low).

# %%
client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = userdata.get('NVIDIA_TOKEN')
)

# %%
def process_health_advice(original_vitals, suggested_vitals):
    """
    Takes original and suggested vitals dictionaries.
    Checks for severe conditions and generates a diet/exercise plan via NVIDIA API.
    Converts Sindhi translation to audio.
    """

    # 1. Identify Changes for the Prompt
    changes = []
    for col in original_vitals:
        diff = suggested_vitals[col] - original_vitals[col]
        if abs(diff) > 0.1:
            direction = "Reduce" if diff < 0 else "Increase"
            changes.append(f"{direction} {col} to {suggested_vitals[col]}")

    change_summary = ", ".join(changes)

    # 2. Safety Logic: Check for Severe Conditions
    # Thresholds: Systolic > 180, Diastolic > 120, BS > 250, Temp > 103
    severe_warning = ""
    is_severe = (
        original_vitals.get('Systolic BP', 0) > 180 or
        original_vitals.get('Diastolic', 0) > 120 or
        original_vitals.get('BS', 0) > 15.0 # Assuming mmol/L based on your 7.8 bound
    )

    if is_severe:
        severe_warning = "CRITICAL: The patient's current vitals are in a danger zone. Start with a medical emergency warning."

    # 3. Construct the AI Prompt
    prompt = f"""
    {severe_warning}
    Original Vitals: {original_vitals}
    Suggested Targets (from DiCE ML): {suggested_vitals}
    Required Changes: {change_summary}

    Task:
    1. Provide specific, nutrient-dense food suggestions to help reach these targets.
    2. Suggest a safe exercise routine based on these vitals.
    3. Output the advice in English, followed by a '---' separator, and then a full translation in Sindhi script (سنڌي).
    """

    # 4. Generate Content (NVIDIA API)
    completion = client.chat.completions.create(
      model="meta/llama-3.1-405b-instruct",
      messages=[{"role": "user", "content": prompt}],
      temperature=0.5,
      max_tokens=2048,
      stream=False
    )

    full_response = completion.choices[0].message.content

    # 5. Handle Sindhi Audio (gTTS)
    if "---" in full_response:
        sindhi_text = full_response.split("---")[-1].strip()
    else:
        sindhi_text = full_response

    try:
        # Generate Audio
        tts = gTTS(text=sindhi_text, lang='sd')
        tts.save("sindhi_prescription.mp3")
        print("\n[✔] Sindhi audio generated: sindhi_prescription.mp3")
    except Exception as e:
        print(f"\n[✘] Audio Error: {e}")

    return full_response

# %%
# --- Integration with your DiCE loop ---
result = process_health_advice(original_vitals, suggested_vitals)
print(result)
# Out:
# [✘] Audio Error: Language not supported: sd
# Based on the provided vitals and targets, here are the suggestions:
#
# **Food Suggestions:**
#
# To help reduce Systolic BP to 112.3 and BMI to 20.0, focus on incorporating the following nutrient-dense foods into your diet:
#
# * Leafy greens like spinach, kale, and collard greens, which are rich in potassium, calcium, and vitamins.
# * Berries, such as blueberries, strawberries, and raspberries, which are high in antioxidants and fiber.
# * Fatty fish like salmon, tuna, and mackerel, which are rich in omega-3 fatty acids.
# * Whole grains like brown rice, quinoa, and whole-wheat bread, which are rich in fiber, vitamins, and minerals.
# * Legumes like lentils, chickpeas, and black beans, which are high in protein, fiber, and potassium.
# * Nuts and seeds like almonds, walnuts, and chia seeds, which are rich in healthy fats, protein, and fiber.
#
# **Exercise Routine:**
#
# Considering your current vitals, a safe exercise routine can include:
#
# * Brisk walking for 30 minutes, 5 days a week
# * Light jogging or cycling for 20-30 minutes, 3-4 days a week
# * Strength training exercises 2-3 times a week, focusing on lower-body exercises like squats, lunges, and leg press
# * High-intensity interval training (HIIT) 2-3 times a week, which can help improve cardiovascular health and burn calories
#
# Remember to consult with a healthcare professional before starting any new exercise routine.
#
# **English Advice:**
#
# To reach your targets, focus on incorporating nutrient-dense foods like leafy greens, berries, fatty fish, whole grains, legumes, and nuts into your diet. For exercise, aim for brisk walking, light jogging or cycling, strength training, and HIIT. Consult with a healthcare professional before starting any new routine.
#
# ---
# **Sindhi Translation (سنڌي):**
#
# توهان جي targets تائين پهچڻ لاءِ، توھان کي کاڌي ۾  nutrient-dense foods جھڙوڪ leafy greens، berries، fatty fish، whole grains، legumes، ۽ nuts شامل ڪرڻ تي زور ڏيڻ گھرجي. وريض لاءِ، توھان کي brisk walking، light jogging يا cycling، strength training، ۽ HIIT تي زور ڏيڻ گھرجي. ڪنھن بھي نئين وريض روٽين شروع ڪرڻ کان پھرين ھيلٿڪيئر پروفيشنل سان مشورو ڪريو.
#
# Note: Please keep in mind that the Sindhi translation is in the Sindhi script, which may not display correctly on all devices or platforms.

# %%
import gtts.lang
print(gtts.lang.tts_langs())
# Out:
# {'af': 'Afrikaans', 'am': 'Amharic', 'ar': 'Arabic', 'bg': 'Bulgarian', 'bn': 'Bengali', 'bs': 'Bosnian', 'ca': 'Catalan', 'cs': 'Czech', 'cy': 'Welsh', 'da': 'Danish', 'de': 'German', 'el': 'Greek', 'en': 'English', 'es': 'Spanish', 'et': 'Estonian', 'eu': 'Basque', 'fi': 'Finnish', 'fr': 'French', 'fr-CA': 'French (Canada)', 'gl': 'Galician', 'gu': 'Gujarati', 'ha': 'Hausa', 'hi': 'Hindi', 'hr': 'Croatian', 'hu': 'Hungarian', 'id': 'Indonesian', 'is': 'Icelandic', 'it': 'Italian', 'iw': 'Hebrew', 'ja': 'Japanese', 'jw': 'Javanese', 'km': 'Khmer', 'kn': 'Kannada', 'ko': 'Korean', 'la': 'Latin', 'lt': 'Lithuanian', 'lv': 'Latvian', 'ml': 'Malayalam', 'mr': 'Marathi', 'ms': 'Malay', 'my': 'Myanmar (Burmese)', 'ne': 'Nepali', 'nl': 'Dutch', 'no': 'Norwegian', 'pa': 'Punjabi (Gurmukhi)', 'pl': 'Polish', 'pt': 'Portuguese (Brazil)', 'pt-PT': 'Portuguese (Portugal)', 'ro': 'Romanian', 'ru': 'Russian', 'si': 'Sinhala', 'sk': 'Slovak', 'sq': 'Albanian', 'sr': 'Serbian', 'su': 'Sundanese', 'sv': 'Swedish', 'sw': 'Swahili', 'ta': 'Tamil', 'te': 'Telugu', 'th': 'Thai', 'tl': 'Filipino', 'tr': 'Turkish', 'uk': 'Ukrainian', 'ur': 'Urdu', 'vi': 'Vietnamese', 'yue': 'Cantonese', 'zh-CN': 'Chinese (Simplified)', 'zh-TW': 'Chinese (Mandarin/Taiwan)', 'zh': 'Chinese (Mandarin)'}

# %%
from openai import OpenAI
from gtts import gTTS
import re

def process_health_advice_urdu(original_vitals, suggested_vitals):
    # 1. Logic for Changes and Safety (keeping your existing logic)
    changes = []
    for col in original_vitals:
        diff = suggested_vitals[col] - original_vitals[col]
        if abs(diff) > 0.1:
            direction = "Reduce" if diff < 0 else "Increase"
            changes.append(f"{direction} {col} to {suggested_vitals[col]}")

    change_summary = ", ".join(changes)

    is_severe = (
        original_vitals.get('Systolic BP', 0) > 180 or
        original_vitals.get('Diastolic', 0) > 120 or
        original_vitals.get('BS', 0) > 15.0
    )
    severe_warning = "CRITICAL: Start with a medical emergency warning." if is_severe else ""

    # 2. Modified Prompt (No asterisks, specific Urdu start)
    prompt = f"""
    {severe_warning}
    Original Vitals: {original_vitals}
    Suggested Targets: {suggested_vitals}

    Task:
    1. Provide specific, nutrient-dense food suggestions to help reach these targets.
    2. Suggest a safe exercise routine based on these vitals.
    3. Output the advice in English, followed by a '---' separator and start the Urdu section immediately with the word 'اردو' followed by the text, make sure to use the urdu names of the food, vegetables and grains.
    4. IMPORTANT: Do not use any asterisks (*) or special markdown characters in the response.
    """

    # 3. Generate Content
    completion = client.chat.completions.create(
      model="meta/llama-3.1-405b-instruct",
      messages=[{"role": "user", "content": prompt}],
      temperature=0.5,
      max_tokens=2048,
      stream=False
    )

    full_response = completion.choices[0].message.content

    # 4. Clean formatting (Remove all asterisks)
    full_response = full_response.replace("*", "")

    # 5. Extract Urdu Text
    if "---" in full_response:
        # Splits and ensures we take everything after the separator
        urdu_part = full_response.split("---")[-1].strip()
        # Find the first occurrence of 'اردو' and keep everything after it
        if "اردو" in urdu_part:
             urdu_text = urdu_part[urdu_part.find("اردو"):]
        else:
             urdu_text = urdu_part
    else:
        urdu_text = full_response

    # 6. Generate Audio
    try:
        tts = gTTS(text=urdu_text, lang='ur')
        tts.save("urdu_prescription.mp3")
        print("\n[✔] Urdu audio generated.")
    except Exception as e:
        print(f"\n[✘] Audio Error: {e}")

    return full_response

# %%
# --- Integration with your DiCE loop ---
result = process_health_advice_urdu(original_vitals, suggested_vitals)
print(result)
# Out:
# [✔] Urdu audio generated.
# To help reach the suggested targets, consider the following advice:
#
# Dietary Suggestions:
#
# - For lowering systolic blood pressure, focus on a diet rich in fruits, vegetables, whole grains, and lean proteins. Specific foods that can help include leafy greens like spinach and kale, which are rich in potassium, and omega-3 fatty acids found in fatty fish like salmon.
# - For maintaining healthy diastolic blood pressure, continue emphasizing potassium-rich foods, along with whole grains like quinoa and brown rice.
# - For blood sugar (BS) management, incorporate foods with a low glycemic index such as whole wheat bread, oats, and non-starchy vegetables like broccoli and bell peppers.
# - To work towards a healthier BMI, focus on nutrient-dense foods that are low in calories but high in fiber and protein, such as lentils, chickpeas, and lean meats like chicken and turkey.
# - Maintaining a healthy body temperature and heart rate can be supported by staying hydrated with plenty of water and limiting caffeine and alcohol.
#
# Exercise Routine:
#
# - Start with moderate-intensity aerobic activities for at least 150 minutes per week. This could include brisk walking, cycling, or swimming.
# - Incorporate strength training exercises at least two days a week to build muscle and boost metabolism. Focus on exercises that work multiple muscle groups at once, such as squats, lunges, and push-ups.
# - Include flexibility exercises like stretching to improve flexibility and balance.
#
# ---
#
# اردو
#
# صحتمند رہنے کے لیے مشورے:
#
# غذائی مشورے:
#
# - سسٹولک بلڈ پریشر کو کم کرنے کے لیے، پھلوں، سبزیوں، پورے اناج، اور لین پروٹین پر مشتمل غذا پر توجہ مرکوز کریں۔ خاص طور پر ایسے کھانے جو مدد کر سکتے ہیں ان میں پالک اور کالی جیسے پتوں والے سبز پتوں والے کھانے شامل ہیں جو پوٹاشیم سے بھرپور ہوتے ہیں، اور فش آئل میں پائے جانے والے اومیگا-3 فیٹی ایسڈز جو سالمون جیسے چربی والی مچھلی میں پائے جاتے ہیں۔
# - صحت مند ڈائیسٹولک بلڈ پریشر کو برقرار رکھنے کے لیے، پوٹاشیم سے بھرپور کھانوں پر توجہ مرکوز کریں، ساتھ ہی پورے اناج جیسے کوئنوا اور براؤن چاول۔
# - بلڈ شوگر (بی ایس) کے انتظام کے لیے، کم گلاسیمک انڈیکس والے کھانوں کو شامل کریں جیسے پورے گندھک کا آٹا، جئی، اور بروکولی اور شملہ مرچ جیسے غیر نشاستے والے سبزیاں۔
# - ایک صحت مند بی ایم آئی کی طرف کام کرنے کے لیے، کالوریز میں کم لیکن فائبر اور پروٹین میں زیادہ غذائیں پر توجہ مرکوز کریں، جیسے دالیں، چنے، اور چکن اور ٹرکی جیسے لین میٹ۔
# - صحت مند جسم کے درجہ حرارت اور دل کی دھڑکن کو برقرار رکھنے میں مدد کرنے والے کافی مقدار میں پانی پینا اور کیفین اور الکوہل کو محدود کرنا شامل ہے۔
#
# ورزش کا معمول:
#
# - ہفتے میں کم سے کم 150 منٹ تک درمیانے شدت کے ایروبک سرگرمیوں سے شروع کریں۔ اس میں تیز پیدل چلنا، سائیکل چلانا، یا تیرنا شامل ہو سکتا ہے۔
# - ہفتے میں کم سے کم دو دن تک مضبوطی کی تربیت کی مشقیں شامل کریں تاکہ پٹھوں کو مضبوط بنایا جا سکے اور میٹابولزم کو بڑھایا جا سکے۔ ایسے مشقیں پر توجہ مرکوز کریں جو ایک ہی وقت میں کئی پٹھوں کے گروپوں کو کام کرتی ہیں، جیسے کہ اسکواٹ، لنگیں، اور پُش اپ۔
# - لچک کی مشقیں جیسے کہ اسٹریچنگ کو شامل کریں تاکہ لچک اور توازن کو بہتر بنایا جا سکے۔
